# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Comcast Telecom Consumer Complaints as complaints
complaints = pd.read_csv("C:\\Users\\kamot\\OneDrive\\Desktop\\1568699544_comcast_telecom_complaints_data\\Comcast_telecom_complaints_data.csv")
#Viewing arbitrary features in the loaded data.
complaints.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0       22-Apr-15   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1       04-Aug-15  10:22:56 AM            Internet   Acworth   Georgia
# 2       18-Apr-15   9:55:47 AM            Internet   Acworth   Georgia
# 3       05-Jul-15  11:59:35 AM            Internet   Acworth   Georgia
# 4       26-May-15   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone
# 0     21009  Closed                          No
# 1     30102  Closed                          No
# 2     30101  Closed                         Yes
# 3     30101    Open                         Yes
# 4     30101  Solved                          No

# %%
#To learn more about the data, we must view the shape, information, and description of the data (observations).
print ("Shape of the data in complaints:", complaints.shape)
print ("----------------------------\n")
print ("Information of the data in complaints:", complaints.info())
print ("\n----------------------------\n")
print ("Description of the data in complaints:", complaints.describe())
# Out:
# Shape of the data in complaints: (2224, 11)
# ----------------------------
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2224 entries, 0 to 2223
# Data columns (total 11 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Ticket #                     2224 non-null   object
#  1   Customer Complaint           2224 non-null   object
#  2   Date                         2224 non-null   object
#  3   Date_month_year              2224 non-null   object
#  4   Time                         2224 non-null   object
#  5   Received Via                 2224 non-null   object
#  6   City                         2224 non-null   object
#  7   State                        2224 non-null   object
#  8   Zip code                     2224 non-null   int64
#  9   Status                       2224 non-null   object
#  10  Filing on Behalf of Someone  2224 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 191.2+ KB
# Information of the data in complaints: None
#
# ----------------------------
#
# Description of the data in complaints:            Zip code
# count   2224.000000
# mean   47994.393435
# std    28885.279427
# min     1075.000000
# 25%    30056.500000
# 50%    37211.000000
# 75%    77058.750000
# max    99223.000000

# %%
# Examining the attributes by data wrangling
complaints.columns
# Out:
# Index(['Ticket #', 'Customer Complaint', 'Date', 'Date_month_year', 'Time',
#        'Received Via', 'City', 'State', 'Zip code', 'Status',
#        'Filing on Behalf of Someone'],
#       dtype='object')

# %%
#Looking for empty values
complaints.isnull().sum()
# Out:
# Ticket #                       0
# Customer Complaint             0
# Date                           0
# Date_month_year                0
# Time                           0
# Received Via                   0
# City                           0
# State                          0
# Zip code                       0
# Status                         0
# Filing on Behalf of Someone    0
# dtype: int64

# %% [markdown]
#                             complaints.dtypes

# %%
#Verifying the datatypes and carry out any necessary conversions.
complaints.dtypes
# Out:
# Ticket #                       object
# Customer Complaint             object
# Date                           object
# Date_month_year                object
# Time                           object
# Received Via                   object
# City                           object
# State                          object
# Zip code                        int64
# Status                         object
# Filing on Behalf of Someone    object
# dtype: object

# %%
#Datetime format conversion for data object
complaints['Date_month_year'] = pd.to_datetime(complaints['Date_month_year'])
complaints.dtypes
# Out:
# Ticket #                               object
# Customer Complaint                     object
# Date                                   object
# Date_month_year                datetime64[ns]
# Time                                   object
# Received Via                           object
# City                                   object
# State                                  object
# Zip code                                int64
# Status                                 object
# Filing on Behalf of Someone            object
# dtype: object

# %%
complaints['Months'] = complaints['Date_month_year'].apply(lambda x: x.month)
complaints['Day'] = complaints['Date_month_year'].apply(lambda x: x.day)
complaints['Day in the week'] = complaints['Date_month_year'].apply(lambda x: x.dayofweek)
import calendar
complaints['Months'] = complaints['Months'].apply(lambda x: calendar.month_abbr[x])
complaints['Day in the  week'] = complaints['Day in the week'].map({0:'Mon',1:'Tue',2:'Wed',3:'Thur',4:'Fri',5:'Sat',6:'Sun'})
complaints.head(5)
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment disappear - service got disconnected  04-08-15
# 2   242732                                  Speed and Service  18-04-15
# 3   277946  Comcast Imposed a New Usage Cap of 300GB that ...  05-07-15
# 4   307175         Comcast not working and no service to boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0      2015-04-22   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1      2015-08-04  10:22:56 AM            Internet   Acworth   Georgia
# 2      2015-04-18   9:55:47 AM            Internet   Acworth   Georgia
# 3      2015-07-05  11:59:35 AM            Internet   Acworth   Georgia
# 4      2015-05-26   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone Months  Day  Day in the week  \
# 0     21009  Closed                          No    Apr   22                2
# 1     30102  Closed                          No    Aug    4                1
# 2     30101  Closed                         Yes    Apr   18                5
# 3     30101    Open                         Yes    Jul    5                6
# 4     30101  Solved                          No    May   26                1
#
#   Day in the  week
# 0              Wed
# 1              Tue
# 2              Sat
# 3              Sun
# 4              Tue

# %%
# Providing a trend chart for the amount of complaints broken down into monthly levels.
month = complaints.groupby('Months')["Ticket #"].count()
print("Maximum number of complaints filed in the month of",month.idxmax(),"considering the number :",month.max())
month = month.reset_index()
# Out:
# Maximum number of complaints filed in the month of Jun considering the number : 1046

# %%
plt.figure(figsize = (10,6))
lp = sns.lineplot(x = 'Months', y= 'Ticket #', data = month)
ax = lp.axes
ax.annotate('June saw the most complaints at 1046.', color='black',
xy = (6, 1080), xycoords = 'data',
xytext = (0.8, 0.85), textcoords = 'axes fraction',
arrowprops = dict(facecolor = 'black', shrink=0.1),
horizontalalignment = 'left', verticalalignment='top')
# Out:
# Text(0.8, 0.85, 'June saw the most complaints at 1046.')

# %%
#Providing a trend chart for the amount of complaints broken down into daily granularity.
complaints['Day in the month'] = pd.to_datetime(complaints['Date'])
daily_complaints_from_comcast_telecom_customers = complaints.set_index(complaints["Day in the month"])
daily_complaints_from_comcast_telecom_customers.head(3)
# Out:
#                  Ticket #                            Customer Complaint  \
# Day in the month
# 2015-04-22         250635                 Comcast Cable Internet Speeds
# 2015-04-08         223441  Payment disappear - service got disconnected
# 2015-04-18         242732                             Speed and Service
#
#                       Date Date_month_year         Time        Received Via  \
# Day in the month
# 2015-04-22        22-04-15      2015-04-22   3:53:50 PM  Customer Care Call
# 2015-04-08        04-08-15      2015-08-04  10:22:56 AM            Internet
# 2015-04-18        18-04-15      2015-04-18   9:55:47 AM            Internet
#
#                       City     State  Zip code  Status  \
# Day in the month
# 2015-04-22        Abingdon  Maryland     21009  Closed
# 2015-04-08         Acworth   Georgia     30102  Closed
# 2015-04-18         Acworth   Georgia     30101  Closed
#
#                  Filing on Behalf of Someone Months  Day  Day in the week  \
# Day in the month
# 2015-04-22                                No    Apr   22                2
# 2015-04-08                                No    Aug    4                1
# 2015-04-18                               Yes    Apr   18                5
#
#                  Day in the  week Day in the month
# Day in the month
# 2015-04-22                    Wed       2015-04-22
# 2015-04-08                    Tue       2015-04-08
# 2015-04-18                    Sat       2015-04-18

# %%
#Scaling the graph up
plt.figure(figsize=(14,6))
plt.suptitle('Complaint volume at daily granularity levels')
plt.ylabel('The quantity of complaints recieved')
daily_complaints_from_comcast_telecom_customers.groupby(pd.Grouper(freq="D")).size().plot(color='orange')
# Out:
# <AxesSubplot:xlabel='Day in the month', ylabel='The quantity of complaints recieved'>

# %%
#amount of complaints based on the day of the week they were filed....More complaints were received on Tuesday and Wednesday.
sns.countplot(x='Day in the week', data = complaints,order=complaints['Day in the week'].value_counts().index, palette ="Reds_d")
# Out:
# <AxesSubplot:xlabel='Day in the week', ylabel='count'>

# %%
complaints['Customer Complaint'] = complaints['Customer Complaint'].str.title()
CT_freq = complaints['Customer Complaint'].value_counts(),
CT_freq
#str.title()—> Lowercases all remaining letters and capitalizes the initial letter of each word.
# Out:
# (Comcast                                                            102
#  Comcast Data Cap                                                    30
#  Comcast Internet                                                    29
#  Comcast Data Caps                                                   21
#  Comcast Billing                                                     18
#                                                                    ...
#  Monthly Data Caps                                                    1
#  Comcast/Xfinity Poor Service, Fraudulent Billing And Collection      1
#  Lost Emails/Billing                                                  1
#  Improper Billing And Non Resolution Of Issues                        1
#  Comcast, Ypsilanti Mi Internet Speed                                 1
#  Name: Customer Complaint, Length: 1740, dtype: int64,)

# %%
complaints.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment Disappear - Service Got Disconnected  04-08-15
# 2   242732                                  Speed And Service  18-04-15
# 3   277946  Comcast Imposed A New Usage Cap Of 300Gb That ...  05-07-15
# 4   307175         Comcast Not Working And No Service To Boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0      2015-04-22   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1      2015-08-04  10:22:56 AM            Internet   Acworth   Georgia
# 2      2015-04-18   9:55:47 AM            Internet   Acworth   Georgia
# 3      2015-07-05  11:59:35 AM            Internet   Acworth   Georgia
# 4      2015-05-26   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone Months  Day  Day in the week  \
# 0     21009  Closed                          No    Apr   22                2
# 1     30102  Closed                          No    Aug    4                1
# 2     30101  Closed                         Yes    Apr   18                5
# 3     30101    Open                         Yes    Jul    5                6
# 4     30101  Solved                          No    May   26                1
#
#   Day in the  week Day in the month
# 0              Wed       2015-04-22
# 1              Tue       2015-04-08
# 2              Sat       2015-04-18
# 3              Sun       2015-05-07
# 4              Tue       2015-05-26

# %%
complaints.Status.unique()
# Out:
# array(['Closed', 'Open', 'Solved', 'Pending'], dtype=object)

# %%
complaints["New_Status"] = ["Open" if Status=="Open" or Status=="Pending" else"Closed"
for Status in complaints["Status"]]

# %%
complaints["New_Status"].unique()
# Out:
# array(['Closed', 'Open'], dtype=object)

# %%
state_of_complaints = pd.crosstab(complaints["State"],complaints["New_Status"])
state_of_complaints
#Checking the status of the ticket by state
# Out:
# New_Status            Closed  Open
# State
# Alabama                   17     9
# Arizona                   14     6
# Arkansas                   6     0
# California               159    61
# Colorado                  58    22
# Connecticut                9     3
# Delaware                   8     4
# District Of Columbia      14     2
# District of Columbia       1     0
# Florida                  201    39
# Georgia                  208    80
# Illinois                 135    29
# Indiana                   50     9
# Iowa                       1     0
# Kansas                     1     1
# Kentucky                   4     3
# Louisiana                 12     1
# Maine                      3     2
# Maryland                  63    15
# Massachusetts             50    11
# Michigan                  92    23
# Minnesota                 29     4
# Mississippi               23    16
# Missouri                   3     1
# Montana                    1     0
# Nevada                     1     0
# New Hampshire              8     4
# New Jersey                56    19
# New Mexico                11     4
# New York                   6     0
# North Carolina             3     0
# Ohio                       3     0
# Oregon                    36    13
# Pennsylvania             110    20
# Rhode Island               1     0
# South Carolina            15     3
# Tennessee                 96    47
# Texas                     49    22
# Utah                      16     6
# Vermont                    2     1
# Virginia                  49    11
# Washington                75    23
# West Virginia              8     3

# %%
plt.figure(figsize=(16,6))
closed=state_of_complaints["Closed"]
opened=state_of_complaints["Open"]
opened.plot(ax=closed.plot(kind="bar",legend=True),color="r",alpha=0.4,legend="True")
plt.xticks(rotation=45,horizontalalignment='right',fontweight='light',fontsize='x-large')
plt.tight_layout()

# %%
pd.crosstab(complaints["State"],complaints["New_Status"]).plot(kind='bar',
                                                               figsize=(16,6),stacked=True,
                                                               title='State wise status of complaints')
# Out:
# <AxesSubplot:title={'center':'State wise status of complaints'}, xlabel='State'>

# %%
# The most complaints come from Georgia
unsolved=state_of_complaints["Open"].sort_values()

# %%
print("State with max unresolved complaints: ",unsolved.idxmax(),unsolved.max())
# Out:
# State with max unresolved complaints:  Georgia 80

# %%
unsolved.plot(kind="bar", figsize=(16,6))
plt.title('Highest percentage of unresolved complaints\n')
plt.tight_layout()

# %%
complaints.head()
# Out:
#   Ticket #                                 Customer Complaint      Date  \
# 0   250635                      Comcast Cable Internet Speeds  22-04-15
# 1   223441       Payment Disappear - Service Got Disconnected  04-08-15
# 2   242732                                  Speed And Service  18-04-15
# 3   277946  Comcast Imposed A New Usage Cap Of 300Gb That ...  05-07-15
# 4   307175         Comcast Not Working And No Service To Boot  26-05-15
#
#   Date_month_year         Time        Received Via      City     State  \
# 0      2015-04-22   3:53:50 PM  Customer Care Call  Abingdon  Maryland
# 1      2015-08-04  10:22:56 AM            Internet   Acworth   Georgia
# 2      2015-04-18   9:55:47 AM            Internet   Acworth   Georgia
# 3      2015-07-05  11:59:35 AM            Internet   Acworth   Georgia
# 4      2015-05-26   1:25:26 PM            Internet   Acworth   Georgia
#
#    Zip code  Status Filing on Behalf of Someone Months  Day  Day in the week  \
# 0     21009  Closed                          No    Apr   22                2
# 1     30102  Closed                          No    Aug    4                1
# 2     30101  Closed                         Yes    Apr   18                5
# 3     30101    Open                         Yes    Jul    5                6
# 4     30101  Solved                          No    May   26                1
#
#   Day in the  week Day in the month New_Status
# 0              Wed       2015-04-22     Closed
# 1              Tue       2015-04-08     Closed
# 2              Sat       2015-04-18     Closed
# 3              Sun       2015-05-07       Open
# 4              Tue       2015-05-26     Closed

# %%
complaints["Received Via"].unique()
# Out:
# array(['Customer Care Call', 'Internet'], dtype=object)

# %%
complaints.New_Status.value_counts()
# Out:
# Closed    1707
# Open       517
# Name: New_Status, dtype: int64

# %%
myexplode = [0.1,0]
plt.title('Complaints Status through the Internet & Customer Care Calls\n')
complaints.New_Status.value_counts().plot(kind='pie',explode =myexplode,autopct='%1.1f%%',
figsize = (14,6))
plt.tight_layout()
# Added autopct='%1.1f%%' to the pie chart to display percentages.

# %%
import nltk

# %%
# !pip install wordcloud
from wordcloud import WordCloud, STOPWORDS
# Out:
# Requirement already satisfied: wordcloud in c:\users\kamot\anaconda3\lib\site-packages (1.8.2.2)
# Requirement already satisfied: matplotlib in c:\users\kamot\anaconda3\lib\site-packages (from wordcloud) (3.5.2)
# Requirement already satisfied: pillow in c:\users\kamot\anaconda3\lib\site-packages (from wordcloud) (9.2.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\kamot\anaconda3\lib\site-packages (from wordcloud) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\kamot\anaconda3\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kamot\anaconda3\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kamot\anaconda3\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kamot\anaconda3\lib\site-packages (from matplotlib->wordcloud) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kamot\anaconda3\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\kamot\anaconda3\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\kamot\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
common = complaints['Customer Complaint'].dropna().tolist()
common =''.join(common).lower()

stop_words = ('Comcast','Now','Company','Day','Someone','Thing','Also','Got','Way','Call','Called','One')

for word in stop_words:
        STOPWORDS.add(word)
        wordcloud = WordCloud(stopwords=STOPWORDS,
background_color='white',
width=1200,
height=1000).generate(common)

# %%
plt.figure( figsize=(10,12) )
plt.imshow(wordcloud)
plt.title('Common terms used in customer complaints')
plt.axis('off')
plt.show()
